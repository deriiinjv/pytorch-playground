# %% [markdown]
# <a href="https://colab.research.google.com/github/deriiinjv/pytorch-playground/blob/main/pytorch-1(rev).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch numpy --quiet

# %%
import torch

# %%
##Tensors
t1=torch.tensor(4.)
t1
t1.dtype
# Out:
# torch.float32

# %%
##vector
t2=torch.tensor([1.,2,3,4])
t2
# Out:
# tensor([1., 2., 3., 4.])

# %%
##matrix
t3=torch.tensor([[5.,6],[7,8],[9,10]])
t3
# Out:
# tensor([[ 5.,  6.],
#         [ 7.,  8.],
#         [ 9., 10.]])

# %%
##3d dimensional array
t4=torch.tensor([[[11,12,13],[13,14,15],[15,16,17],[17,18,19.]]])
t4
# Out:
# tensor([[[11., 12., 13.],
#          [13., 14., 15.],
#          [15., 16., 17.],
#          [17., 18., 19.]]])

# %%
print(t1)
t1.shape
# Out:
# tensor(4.)
# torch.Size([])

# %%
print(t2)
t2.shape
# Out:
# tensor([1., 2., 3., 4.])
# torch.Size([4])

# %%
print(t3)
t3.shape
# Out:
# tensor([[ 5.,  6.],
#         [ 7.,  8.],
#         [ 9., 10.]])
# torch.Size([3, 2])

# %%
print(t4)
t4.shape
# Out:
# tensor([[[11., 12., 13.],
#          [13., 14., 15.],
#          [15., 16., 17.],
#          [17., 18., 19.]]])
# torch.Size([1, 4, 3])

# %% [markdown]
# **Tensor operations and gradients**

# %%
#create tensors
x=torch.tensor(3.)
w=torch.tensor(4.,requires_grad=True)
b=torch.tensor(5.,requires_grad=True)
x,w,b
# Out:
# (tensor(3.), tensor(4., requires_grad=True), tensor(5., requires_grad=True))

# %%
##arithmetic operations
y=w*x+b
y
# Out:
# tensor(17., grad_fn=<AddBackward0>)

# %%
##compute derivatives
y.backward()

# %%
#Display gradients
print('dy/dx:',x.grad)
print('dy/dw:',w.grad)
print('dy/db:',b.grad)
# Out:
# dy/dx: None
# dy/dw: tensor(3.)
# dy/db: tensor(1.)

# %% [markdown]
# **Interoperability with Numpy**

# %%
import numpy as np
x=np.array([[1,2],[3,4]])
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
# numpy to torch tensor
y=torch.from_numpy(x)
y
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
x.dtype,y.dtype
# Out:
# (dtype('int64'), torch.int64)

# %%
##torch tensor to numpy
z=y.numpy()
z
# Out:
# array([[1, 2],
#        [3, 4]])
